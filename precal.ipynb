# %% [markdown]
# <a href="https://colab.research.google.com/github/penteler/mpcov/blob/main/precal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Get data

# %% [markdown]
# #From .csv files linked here

# %%
import pandas as pd
from google.colab import files
import io

#url = "https://people.sc.fsu.edu/~jburkardt/data/csv/cities.csv"

url = "https://people.sc.fsu.edu/~jburkardt/data/csv/letter_frequency.csv"

table_1 = pd.read_csv(url)

table_1.head()
table_1.describe()
# Out:
#         "Frequency"   "Percentage"
# count  2.600000e+01      26.000000
# mean   1.157192e+07       3.850000
# std    1.007224e+07       3.339731
# min    9.317200e+04       0.000000
# 25%    4.857968e+06       1.625000
# 50%    7.754634e+06       2.600000
# 75%    1.880938e+07       6.225000
# max    3.790712e+07      12.600000

# %% [markdown]
# #From an uploaded.csv

# %%
import pandas as pd
from google.colab import files
import io

#dailog to upload files:
uploaded = files.upload()
#the files dailogue has been stored as the `uploaded` variable
file_name = next(iter(uploaded))
table_1 = pd.read_csv(io.BytesIO(uploaded[file_name]))
table_1

# %% [markdown]
# #From a table on a webpage

# %%
import pandas as pd
import numpy as np

#URL = "https://en.wikipedia.org/wiki/Philadelphia_Phillies"
URL = "https://gadgetversus.com/processor/apple-m2-vs-amd-ryzen-5-4500u/"
tables = pd.read_html(URL)
print("There are : ",len(tables)," tables")
print("Take a look at the table:")
table_1 = tables[1]
table_1
# Out:
# There are :  10  tables
# Take a look at the table:
#                                                     0   1  \
# 0                                           Processor NaN
# 1                                       Market (main) NaN
# 2                                                 ISA NaN
# 3                                   Microarchitecture NaN
# 4                                           Core name NaN
# 5                                              Family NaN
# 6                              Part number(s), S-Spec NaN
# 7                                        Release date NaN
# 8                                         Lithography NaN
# 9                                         Transistors NaN
# 10                                              Cores NaN
# 11                                            Threads NaN
# 12                                     Base frequency NaN
# 13                                    Turbo frequency NaN
# ...
